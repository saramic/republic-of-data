# %% [markdown]
# # What is calendar.txt?
#
# A calendar of every day between 2000-01-01 - 2020-05-14 in particular showing
#
# - **transport_day**
#
#     'Saturday' 'Sunday' 'Public Holiday' 'Weekday' 'Free Travel'
#
#
# - **day_or_end**
#
#     'Weekend' 'Public Holiday' 'Weekday' 'Free Travel'
#
#
# - **day_type**
#
#     'School Holiday Saturday' 'School Holiday Sunday' 'Public Holiday' 'School Holiday Weekday' 'Normal Weekday' 'Normal Saturday' 'Normal Sunday' 'Free Travel' 'Saturday' 'Sunday' '0'
#
# ## Questions?
#
# - need better names
# - are they consistent between each other?
# - still some question marks in the fields

# %%
import pandas as pd

calendar_df = pd.read_csv("../MelbDatathon2018/calendar.txt", 
                          sep="|",
                          header=None,
                          index_col=False,
                          names=[
                              'yyyymmdd',
                              'date',
                              'year',
                              'financial year',
                              'number_4?',
                              'month',
                              'yyyymm',
                              'quarter',
                              'fy_quarter',
                              'week?',
                              '10' ,
                              'transport_day',
                              'day_or_end',
                              'day_type',
                              'day_of_week',
                              'day',
                              'yyyy??',
                              'MMM YY/',
                              'M',
                              'number_19?',
                              'week ending?'
                          ]
                         )


select_column_names = [
    'year', 'financial year', 'transport_day', 'number_4?', 'month', 'quarter', 'week?', '10', 'transport_day',
    'day_or_end', 'day_type', 'day_of_week', 'day', 'yyyy??', 'MMM YY/', 'M', 'number_19?', 'week ending?'
]
for column_name in select_column_names:
    print(column_name, calendar_df.sort_values(['yyyymmdd'])[column_name].unique())
# Out:
# year [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#  2015 2016 2017 2018 2019 2020]
# financial year ['FY1999 - 2000' 'FY2000 - 2001' 'FY2001 - 2002' 'FY2002 - 2003'
#  'FY2003 - 2004' 'FY2004 - 2005' 'FY2005 - 2006' 'FY2006 - 2007'
#  'FY2007 - 2008' 'FY2008 - 2009' 'FY2009 - 2010' 'FY2010 - 2011'
#  'FY2011 - 2012' 'FY2012 - 2013' 'FY2013 - 2014' 'FY2014 - 2015'
#  'FY2015 - 2016' 'FY2016 - 2017' 'FY2017 - 2018' 'FY2018 - 2019'
#  'FY2019 - 2020']
# transport_day ['Saturday' 'Sunday' 'Public Holiday' 'Weekday' 'Free Travel']
# number_4? [13 14 15 16 17 18  7  8  9 10 11 12]
# month ['January' 'February' 'March' 'April' 'May' 'June' 'July' 'August'
#  'September' 'October' 'November' 'December']
# quarter ['2000Q1' '2000Q2' '2000Q3' '2000Q4' '2001Q1' '2001Q2' '2001Q3' '2001Q4'
#  '2002Q1' '2002Q2' '2002Q3' '2002Q4' '2003Q1' '2003Q2' '2003Q3' '2003Q4'
#  '2004Q1' '2004Q2' '2004Q3' '2004Q4' '2005Q1' '2005Q2' '2005Q3' '2005Q4'
# ...
