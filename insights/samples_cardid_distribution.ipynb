# %%
import pandas as pd
print(pd.__version__)
pd.options.display.max_rows = 50

import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="../MelbDatathon2018/Auth/engine_Republic_of_Data_2018-afb04b72bd54.json"
# %matplotlib inline
# Out:
# 0.23.3

# %%
# %load_ext google.cloud.bigquery
# Out:
# /Applications/anaconda/envs/py3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Applications/anaconda/envs/py3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# %%bigquery df_cardid_0_on
# SELECT distinct cardid FROM `republic-of-data-2018.data.samp_0_scan_on`

# %%
df_cardid_0_on.plot(kind = 'hist', figsize=(10, 10))

# %%
# %%bigquery df_cardid_0_off
# SELECT distinct cardid FROM `republic-of-data-2018.data.samp_0_scan_off`
# Out:
#            cardid
# 0        15911240
# 1        16975110
# 2         6741530
# 3        17692690
# 4         7780990
# 5        13361340
# 6        20581060
# 7        18799980
# 8        17609540
# 9         5475800
# 10       19225850
# 11        3035130
# 12       11250410
# 13        3464080
# 14        9003610
# 15       10949510
# 16       12285880
# 17       19865300
# 18       13110990
# 19       10312550
# 20       19522680
# 21        3240720
# 22       14678730
# 23       12936180
# 24       16906420
# ...           ...
# 1420566  22809010
# 1420567  21931640
# 1420568  11726630
# 1420569   2472360
# 1420570   6240670
# 1420571   7328190
# 1420572   1705970
# 1420573   1301000
# 1420574  22658200
# 1420575   8692100
# 1420576   7111880
# 1420577   5342970
# 1420578   1162910
# 1420579   8895010
# 1420580   7394260
# 1420581   9153360
# 1420582  15530090
# 1420583   8440690
# 1420584  23777020
# 1420585  21877480
# 1420586  20812540
# 1420587  15446050
# 1420588  17670290
# ...

# %%
df_cardid_0_off.plot(kind = 'hist', figsize=(10, 10))

# %%
# %%bigquery df_cardid_1_on
# SELECT distinct cardid FROM `republic-of-data-2018.data.samp_1_scan_on`
# Out:
#            cardid
# 0        14301341
# 1         6256671
# 2         3783831
# 3        10778221
# 4        13542041
# 5        23118241
# 6        16933271
# 7         6030951
# 8        23231421
# 9        23659631
# 10       22818121
# 11       14584061
# 12       13279021
# 13        5685681
# 14       13044151
# 15       16287151
# 16       10692011
# 17       12709431
# 18       21610791
# 19       18509431
# 20       14167621
# 21        3176741
# 22        5219971
# 23       17032061
# 24        6113461
# ...           ...
# 1506162  17746361
# 1506163  19874291
# 1506164  23941221
# 1506165  22096781
# 1506166  21363301
# 1506167   1071071
# 1506168  18610421
# 1506169  20894371
# 1506170  20010861
# 1506171  19903901
# 1506172  11496661
# 1506173  16737611
# 1506174  22153781
# 1506175  14321841
# 1506176  23520421
# 1506177  23292001
# 1506178  19991031
# 1506179  22570441
# 1506180  23564641
# 1506181  19214581
# 1506182  22093401
# 1506183  19223221
# 1506184  24414871
# ...

# %%
df_cardid_1_on.plot(kind = 'hist', figsize=(10, 10))

# %%
# %%bigquery df_cardid_1_off
# SELECT distinct cardid FROM `republic-of-data-2018.data.samp_1_scan_off`
# Out:
#            cardid
# 0         1590181
# 1        15631771
# 2        20094461
# 3         3117051
# 4        14972471
# 5         1610631
# 6        12595511
# 7        16110441
# 8        17704291
# 9        16270311
# 10       15918671
# 11       10302531
# 12       19451501
# 13        9603901
# 14        1646271
# 15       13434801
# 16        6938591
# 17       17821761
# 18       12647131
# 19       22490751
# 20       16819611
# 21       19227281
# 22       12320171
# 23       11410061
# 24        1582661
# ...           ...
# 1421597  21456191
# 1421598   6054821
# 1421599  16119051
# 1421600  15162201
# 1421601  23909331
# 1421602   5654931
# 1421603   6863201
# 1421604  14261291
# 1421605   5562151
# 1421606  18515161
# 1421607  14802081
# 1421608   1646711
# 1421609   1772501
# 1421610  10260401
# 1421611  18705401
# 1421612  15677551
# 1421613  20578141
# 1421614  24088101
# 1421615  16982581
# 1421616  10577131
# 1421617   2596441
# 1421618  13647781
# 1421619  23584561
# ...

# %%
df_cardid_1_off.plot(kind = 'hist', figsize=(10, 10))
